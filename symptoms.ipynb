# %%
# Imports
import pandas as pd
import numpy as np
from numpy import nan
from imblearn.over_sampling import RandomOverSampler

import matplotlib.pyplot as plt
import sklearn
import matplotlib.pyplot as plt
from sklearn import model_selection
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.model_selection import KFold

from random import seed
from random import randint

print("Done importing")
# Out:
# Done importing

# %%
#Upload file
df=pd.read_csv("data/diagnostictool.csv")
print("Done uploading")
# Out:
# Done uploading

# %%
df.head()
# Out:
#    ICD10                                        Description  \
# 0  A09.0  Other and unspecified gastroenteritis and coli...
# 1  A09.9  Gastroenteritis and colitis of unspecified origin
# 2    B24  Unspecified human immunodeficiency virus [HIV]...
# 3  D50.9               Iron deficiency anaemia, unspecified
# 4  E03.9                        Hypothyroidism, unspecified
#
#                Symptom1     Symptom2              Symptom3  \
# 0                Chills  Dehydration              Diarrhea
# 1                Chills  Dehydration              Diarrhea
# 2         Chronic Cough     Diarrhea  Difficulty Breathing
# 3  Difficulty Breathing    Dizziness               Fatigue
# 4        Blurred Vision  Coarse Hair      Cold Intolerance
#
#                 Symptom4           Symptom5            Symptom6  \
# 0              Dry Mouth           Dry Skin               Fever
# 1              Dry Mouth           Dry Skin               Fever
# 2  Difficulty Swallowing            Fatigue               Fever
# 3           Palpitations                NaN                 NaN
# 4           Constipation  Decreased Hearing  Decreased Sweating
#
#                                       Symptom7      Symptom8    ...     \
# 0                             Increased Thirst       Malaise    ...
# 1                             Increased Thirst       Malaise    ...
# 2  Fungal Infection Of The Mouth And Esophagus  Fungal Nails    ...
# 3                                          NaN           NaN    ...
# 4                                   Depression      Dry Hair    ...
#
#                    Symptom23              Symptom24     Symptom25 Symptom26  \
# 0                        NaN                    NaN           NaN       NaN
# 1                        NaN                    NaN           NaN       NaN
# 2                   Vomiting            Weight Loss  White Tongue       NaN
# 3                        NaN                    NaN           NaN       NaN
# 4  Thyroid Gland Enlargement  Trouble Concentrating   Weight Gain       NaN
#
#   Symptom27 Symptom28 Symptom29 Symptom30 Symptom31 Symptom32
# 0       NaN       NaN       NaN       NaN       NaN       NaN
# 1       NaN       NaN       NaN       NaN       NaN       NaN
# 2       NaN       NaN       NaN       NaN       NaN       NaN
# 3       NaN       NaN       NaN       NaN       NaN       NaN
# 4       NaN       NaN       NaN       NaN       NaN       NaN
#
# [5 rows x 34 columns]

# %%
def symptom_to_numeric(x):
    if str(x)=='nan':
        return "0"
    uniqueSymptoms= pd.unique(df[df.columns[2:len(df.columns)]].values.ravel())
    for index, symptom in enumerate(uniqueSymptoms):
        if x==symptom:
            return str(index+1)

# %%
def icd_to_numeric(x):
    icd10= pd.unique(df['ICD10'].values.ravel())
    for index, icd in enumerate(icd10):
        if x==icd:
            return str(index)

# %%
#Visualize amount of empty variables per columns
df.isnull().mean()
# Out:
# ICD10          0.00
# Description    0.00
# Symptom1       0.00
# Symptom2       0.00
# Symptom3       0.02
# Symptom4       0.02
# Symptom5       0.08
# Symptom6       0.12
# Symptom7       0.18
# Symptom8       0.22
# Symptom9       0.24
# Symptom10      0.30
# Symptom11      0.32
# Symptom12      0.40
# Symptom13      0.52
# Symptom14      0.66
# Symptom15      0.72
# Symptom16      0.76
# Symptom17      0.76
# Symptom18      0.80
# Symptom19      0.82
# Symptom20      0.84
# Symptom21      0.84
# Symptom22      0.86
# Symptom23      0.90
# Symptom24      0.92
# Symptom25      0.92
# Symptom26      0.98
# Symptom27      0.98
# Symptom28      0.98
# Symptom29      0.98
# Symptom30      0.98
# Symptom31      0.98
# Symptom32      0.98
# dtype: float64

# %%
# Discard columns with more than 50% empty variables
df_reduced= df.loc[:, :'Symptom12']
df_reduced.head()
# Out:
#    ICD10                                        Description  \
# 0  A09.0  Other and unspecified gastroenteritis and coli...
# 1  A09.9  Gastroenteritis and colitis of unspecified origin
# 2    B24  Unspecified human immunodeficiency virus [HIV]...
# 3  D50.9               Iron deficiency anaemia, unspecified
# 4  E03.9                        Hypothyroidism, unspecified
#
#                Symptom1     Symptom2              Symptom3  \
# 0                Chills  Dehydration              Diarrhea
# 1                Chills  Dehydration              Diarrhea
# 2         Chronic Cough     Diarrhea  Difficulty Breathing
# 3  Difficulty Breathing    Dizziness               Fatigue
# 4        Blurred Vision  Coarse Hair      Cold Intolerance
#
#                 Symptom4           Symptom5            Symptom6  \
# 0              Dry Mouth           Dry Skin               Fever
# 1              Dry Mouth           Dry Skin               Fever
# 2  Difficulty Swallowing            Fatigue               Fever
# 3           Palpitations                NaN                 NaN
# 4           Constipation  Decreased Hearing  Decreased Sweating
#
#                                       Symptom7      Symptom8        Symptom9  \
# 0                             Increased Thirst       Malaise     Muscle Pain
# 1                             Increased Thirst       Malaise     Muscle Pain
# 2  Fungal Infection Of The Mouth And Esophagus  Fungal Nails  Groin Swelling
# 3                                          NaN           NaN             NaN
# 4                                   Depression      Dry Hair        Dry Skin
#
#   Symptom10       Symptom11     Symptom12
# 0    Nausea  Stomach Cramps  Stomach Pain
# 1    Nausea  Stomach Cramps  Stomach Pain
# 2  Headache         Malaise  Malignancies
# 3       NaN             NaN           NaN
# 4   Fatigue   Forgetfulness     Hair Loss

# %%
#Create dummy variables
dfdum=pd.DataFrame()
for column in df_reduced:
    if column!="ICD10" and column!="Description":
        dfdum[column]= df[column].apply(symptom_to_numeric)
    else:
        dfdum[column]= df[column]

# %%
dfdum.pop('Description')
dfdum.head()
# Out:
#    ICD10 Symptom1 Symptom2 Symptom3 Symptom4 Symptom5 Symptom6 Symptom7  \
# 0  A09.0        1        2        3        4        5        6        7
# 1  A09.9        1        2        3        4        5        6        7
# 2    B24       15        3       16       17       18        6       19
# 3  D50.9       16       36       18       37        0        0        0
# 4  E03.9       38       39       40       41       42       43       44
#
#   Symptom8 Symptom9 Symptom10 Symptom11 Symptom12
# 0        8        9        10        11        12
# 1        8        9        10        11        12
# 2       20       21        22         8        23
# 3        0        0         0         0         0
# 4       45        5        18        46        47

# %%
#Generate artificial dataset with 10000 patients [to train AI models on]
num_symptoms = len(pd.unique(df[df.columns[2:len(df.columns)]].values.ravel()))
fake_patients=[]
# generate some integers
for n in range (10000):
    patient=[]
    for _ in range(12):
        value = randint(0, num_symptoms)
        patient.append(value)
    fake_patients.append(patient)
fake_patients[:5]
# Out:
# [[40, 156, 143, 189, 71, 191, 90, 243, 0, 229, 198, 41],
#  [43, 166, 199, 79, 36, 146, 224, 23, 1, 23, 131, 130],
#  [105, 128, 12, 183, 226, 236, 246, 9, 236, 213, 176, 84],
#  [246, 86, 236, 60, 166, 148, 219, 200, 104, 160, 179, 66],
#  [19, 17, 81, 154, 79, 221, 99, 245, 82, 222, 82, 119]]

# %%
# Assign ICD10 to each fake patient using 1-nn        
y = dfdum.pop('ICD10')
X = dfdum
knn = KNeighborsClassifier(n_neighbors=1)  
knn.fit(X, y)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=1, p=2,
#            weights='uniform')

# %%
fake_icd = knn.predict(fake_patients)  
fake_icd[:5]
# Out:
# array(['I50.0', 'J01.4', 'J00', 'K21.9', 'I50.0'], dtype=object)

# %%
# Split-out validation dataset

validation_size = 0.20
seed = 7
scoring='accuracy'
X_train, X_validation, y_train, y_validation = model_selection.train_test_split(fake_patients, fake_icd, test_size=validation_size, random_state=seed)
y_train = [icd_to_numeric(x) for x in y_train]
y_validation=[icd_to_numeric(x) for x in y_validation]

# %%
# Spot Check Algorithms
models = []
models.append(('LR', LogisticRegression()))
models.append(('LDA', LinearDiscriminantAnalysis()))
models.append(('KNN', KNeighborsClassifier()))
models.append(('CART', DecisionTreeClassifier()))
models.append(('NB', GaussianNB()))
models.append(('SVM', SVC(kernel="linear", probability=True)))
# evaluate each model in turn
results = []
names = []
for name, model in models:
	kfold = model_selection.KFold(n_splits=10, random_state=seed)
	cv_results = model_selection.cross_val_score(model, X_train, y_train, cv=kfold, scoring=scoring)
	results.append(cv_results)
	names.append(name)
	msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
	print(msg)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# LR: 0.799125 (0.015197)
# LDA: 0.852500 (0.015021)
# KNN: 0.613375 (0.014297)
# CART: 0.436875 (0.018827)
# NB: 0.776500 (0.024101)
# SVM: 0.907000 (0.009572)
